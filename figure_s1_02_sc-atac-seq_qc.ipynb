# %% [markdown]
# # load library

# %%
source("r/jupyter_common.R")
source("r/identify_cell_types.R")
source("r/plot_sc_clusters.R")

# %%
suppressPackageStartupMessages(library(Seurat))
suppressPackageStartupMessages(library(ArchR))

suppressPackageStartupMessages(library(RColorBrewer))
suppressPackageStartupMessages(library(ggplot2))
suppressPackageStartupMessages(library(IRdisplay))

# %% [markdown]
# # patameters

# %% [markdown]
# no parameters since this jupyter notebook shows the QC output files generated by scATAC-seq pipeline instead of generating figures inside this notebook.

# %% [markdown]
# # read scATAC-seq

# %%
dir_atac <- "/home/hkim77/francolab.w/sc-atac-seq/male-bc/run-20220725"
dir_output <- sprintf("%s/output_male-bc", dir_atac)
dir_output_p2g <- sprintf("%s/output_p2g_male-bc", dir_atac)
fname_atac <- sprintf("%s/rds/male-bc_archrproj_obj_final.rds", dir_output)

atac <- readRDS(fname_atac)
atac
# Out:
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /datastore/nextgenout5/share/labs/francolab/hyunsoo.kim/sc-atac-seq/male-bc/run-20220725/output_male-bc/archr_output
# samples(2): 4CC61L 446B7L
# sampleColData names(1): ArrowFiles
# cellColData names(47): Sample TSSEnrichment ... RNA_harmony_th.0
#   cluster.type.harmony
# numberOfCells(1): 10379
# medianTSS(1): 10.012
# medianFrags(1): 6247

# %% [markdown]
# # 446B7L

# %%
idxSample <- BiocGenerics::which(atac$Sample %in% "446B7L")
cellsSample <- atac$cellNames[idxSample]
atac.446B7L <- atac[cellsSample, ]

nCells(atac.446B7L)
# Out:
# [1] 6660

# %%
df_col <- as.data.frame(getCellColData(atac.446B7L))
t(head(df_col))
# Out:
#                       446B7L#AAAGGGCCAGAGCCAA-1 446B7L#TTAGCGAGTCTGGTCG-1
# Sample                446B7L                    446B7L
# TSSEnrichment          7.220                    10.039
# ReadsInTSS            3799                      7128
# ReadsInPromoter       4708                      7975
# ReadsInBlacklist      343                       296
# PromoterRatio         0.08020990                0.13630149
# PassQC                1                         1
# NucleosomeRatio       2.9875000                 1.4598503
# nMultiFrags           2827                      2379
# nMonoFrags             7360                     11893
# nFrags                29348                     29255
# nDiFrags              19161                     14983
# DoubletScore          0                         0
# DoubletEnrichment     0.1906977                 0.3023256
# BlacklistRatio        0.005843669               0.005058964
# ATAC_clusters         C7                        C2
# ...

# %% [markdown]
# ## TSS enrichment

# %%
fname_png <- sprintf("%s/png/male-bc_446B7L_tss.png", dir_output)
display_png(file=fname_png, width=900, height=1900)

# %% [markdown]
# ## n fragments

# %%
fname_png <- sprintf("%s/png/male-bc_446B7L_depth.png", dir_output)
display_png(file=fname_png, width=900, height=1900)

# %% [markdown]
# ## QC

# %%
fname_png <- sprintf("%s/png/male-bc_446B7L_qc.png", dir_output)
display_png(file=fname_png, width=900, height=1900)

# %% [markdown]
# ## doublet enrichment

# %%
fname_png <- sprintf("%s/png/male-bc_446B7L_doublets.png", dir_output)
display_png(file=fname_png, width=900, height=1900)

# %% [markdown]
# # 4CC61L

# %%
idxSample <- BiocGenerics::which(atac$Sample %in% "4CC61L")
cellsSample <- atac$cellNames[idxSample]
atac.4CC61L <- atac[cellsSample, ]

nCells(atac.4CC61L)
# Out:
# [1] 3719

# %%
df_col <- as.data.frame(getCellColData(atac.4CC61L))
t(head(df_col))
# Out:
#                       4CC61L#AAAGGGCGTGCTGGCT-1
# Sample                4CC61L
# TSSEnrichment         7.926
# ReadsInTSS            4351
# ReadsInPromoter        4927
# ReadsInBlacklist      1005
# PromoterRatio         0.03851927
# PassQC                1
# NucleosomeRatio       0.5533992
# nMultiFrags           3370
# nMonoFrags            41171
# nFrags                63955
# nDiFrags              19414
# DoubletScore          0
# DoubletEnrichment     0.4619048
# BlacklistRatio        0.007857087
# ATAC_clusters         C8
# predictedCell_ArchR   4CC61L#CTATCCGGTTTGTTGG-1
# predictedGroup_ArchR  7-Macrophages
# predictedScore_ArchR  0.5141806
# Mode.Label            TRUE
# ReadsInPeaks           6708
# FRIP                  0.05269111
# Cancer.Group          Normal
# nCount_RNA             7017
# nFeature_RNA          2318
# percent.mt            6.142226
# Phase                 S
# RNA_snn_res.0.2       9
# seurat_clusters       9
# epi_krt_epcam         nonepi
# ...

# %% [markdown]
# ## TSS enrichment

# %%
fname_png <- sprintf("%s/png/male-bc_4CC61L_tss.png", dir_output)
display_png(file=fname_png, width=900, height=1900)

# %% [markdown]
# ## n fragments

# %%
fname_png <- sprintf("%s/png/male-bc_4CC61L_depth.png", dir_output)
display_png(file=fname_png, width=900, height=1900)

# %% [markdown]
# ## QC

# %%
fname_png <- sprintf("%s/png/male-bc_4CC61L_qc.png", dir_output)
display_png(file=fname_png, width=900, height=1900)

# %% [markdown]
# ## doublet enrichment

# %%
fname_png <- sprintf("%s/png/male-bc_4CC61L_doublets.png", dir_output)
display_png(file=fname_png, width=900, height=1900)
